# %% [markdown]
# # Logistic Regression.
#
#   - What is it ?
#
#   Used for classification problems, specially binary classification.
#
#   - Why can't we use Linear Regression ?
#
#   Linear Regression is useful for continuous prediction, if we use linear regression for classification although the logistic regression do the same like get the result in any form of a real valued number that can be negetive or positive. but here is what logistic does different than linear, linear just gives a real valued number result that is not useful for classification.

# %% [markdown]
# Question:
#
# If Logistic Regression is basically a Linear Regression output passed through a sigmoid function, why don't we simply use Linear Regression + Sigmoid?
#
# (Current understanding)
#
# Logistic Regression is designed together with a different loss function that makes optimization more suitable for binary classification.
#
# We will study this after learning loss functions.
